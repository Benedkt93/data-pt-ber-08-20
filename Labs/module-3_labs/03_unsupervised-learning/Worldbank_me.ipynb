# %%
pip install world_bank_data --upgrade
# Out:
# Requirement already up-to-date: world_bank_data in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (0.1.3)
# Requirement already satisfied, skipping upgrade: cachetools in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from world_bank_data) (4.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied, skipping upgrade: requests in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from world_bank_data) (2.24.0)
# Requirement already satisfied, skipping upgrade: pandas in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from world_bank_data) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from requests->world_bank_data) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from requests->world_bank_data) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from requests->world_bank_data) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from requests->world_bank_data) (1.25.10)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from pandas->world_bank_data) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from pandas->world_bank_data) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from pandas->world_bank_data) (1.19.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\broth\anaconda3\envs\kittycat\lib\site-packages (from python-dateutil>=2.7.3->pandas->world_bank_data) (1.15.0)

# %%
import pandas as pd
import world_bank_data as wb
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
indicators = ["SP.POP.TOTL","NY.GDP.MKTP.CD","NY.GDP.PCAP.CD",'SP.DYN.LE00.IN','SH.STA.DIAB.ZS','EN.ATM.CO2E.PC','SE.PRM.ENRL.TC.ZS','SL.UEM.TOTL.ZS','SE.XPD.TOTL.GD.ZS','SP.RUR.TOTL.ZS','EG.FEC.RNEW.ZS','EN.ATM.PM25.MC.ZS']
from functools import reduce
data_all = []
for i in range(0, (len(indicators))):
    data = pd.DataFrame(wb.get_series(indicators[i],mrv=1)).reset_index()
    data = data.drop(labels=['Series','Year'],axis='columns')
    data_all.append(data)
    
data_all
df = reduce(lambda df1,df2: pd.merge(df1,df2,on='Country'), data_all).rename(columns={"SP.POP.TOTL":'population',"NY.GDP.MKTP.CD":'GDP_in_Dollar','NY.GDP.PCAP.CD':'gdp_per_cap','SP.DYN.LE00.IN':'life_exp','SH.STA.DIAB.ZS':'diabetes_percent','EN.ATM.CO2E.PC':'co2_per_cap','SL.UEM.TOTL.ZS':'unemp','SE.PRM.ENRL.TC.ZS':'teacher','SP.RUR.TOTL.ZS':'rural_pop','EG.FEC.RNEW.ZS':'renewable_percent','SE.XPD.TOTL.GD.ZS':'educat_expen','EN.ATM.PM25.MC.ZS':'airplution'})
df
# Out:
#                             Country    population  GDP_in_Dollar  \
# 0                        Arab World  4.278703e+08   2.817415e+12
# 1            Caribbean small states  7.401383e+06   7.772171e+10
# 2    Central Europe and the Baltics  1.023786e+08   1.668852e+12
# 3        Early-demographic dividend  3.290291e+09   1.198987e+13
# 4               East Asia & Pacific  2.340628e+09   2.698777e+13
# ..                              ...           ...            ...
# 259           Virgin Islands (U.S.)  1.066310e+05            NaN
# 260              West Bank and Gaza  4.685306e+06            NaN
# 261                     Yemen, Rep.  2.916192e+07   2.258108e+10
# 262                          Zambia  1.786103e+07   2.330977e+10
# 263                        Zimbabwe  1.464547e+07   2.144076e+10
#
#       gdp_per_cap   life_exp  diabetes_percent  co2_per_cap  teacher  \
# 0     6584.740241  71.806825         12.536001     4.712845      NaN
# 1    10500.971902  73.637109         11.629346     8.490807      NaN
# 2    16300.792072  76.976845          6.296002     6.377623      NaN
# 3     3644.014598  70.483191         10.090910     2.345693      NaN
# 4    11530.138135  76.068336          8.202608     6.071789      NaN
# ..            ...        ...               ...          ...      ...
# 259           NaN  79.568293         12.300000          NaN      NaN
# 260           NaN  73.895000          9.500000     0.740607      NaN
# 261    774.334490  66.096000          5.400000     0.390480      NaN
# 262   1305.063254  63.510000          4.500000     0.314183      NaN
# 263   1463.985910  61.195000          1.800000     0.782777      NaN
#
#          unemp  educat_expen  rural_pop  renewable_percent  airplution
# 0    10.191472           NaN  40.798353           4.094037  100.000000
# 1     8.092527       5.16919  48.630009           8.825977   99.998738
# 2     3.641848           NaN  37.561644          17.121893   97.949799
# 3     5.844164           NaN  54.459204          25.554845   99.353070
# 4     3.897888           NaN  40.113467          13.857603   96.877523
# ..         ...           ...        ...                ...         ...
# 259   8.759000           NaN   4.168000           3.877525   40.000000
# 260  26.098000           NaN  23.560000          10.472715  100.000000
# 261  12.830000           NaN  62.727000           2.276417  100.000000
# 262  11.412000           NaN  55.928000          87.985452  100.000000
# 263   4.991000           NaN  67.790000          81.797809  100.000000
#
# [264 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# Country                0
# population             2
# GDP_in_Dollar         34
# gdp_per_cap           34
# life_exp              20
# diabetes_percent       8
# co2_per_cap           16
# teacher              260
# unemp                 31
# educat_expen         247
# rural_pop              4
# renewable_percent      5
# airplution            24
# dtype: int64

# %%
# Dropping teacher & educat_expen

# %%
df.set_index('Country')
# Out:
#                                   population  GDP_in_Dollar   gdp_per_cap  \
# Country
# Arab World                      4.278703e+08   2.817415e+12   6584.740241
# Caribbean small states          7.401383e+06   7.772171e+10  10500.971902
# Central Europe and the Baltics  1.023786e+08   1.668852e+12  16300.792072
# Early-demographic dividend      3.290291e+09   1.198987e+13   3644.014598
# East Asia & Pacific             2.340628e+09   2.698777e+13  11530.138135
# ...                                      ...            ...           ...
# Virgin Islands (U.S.)           1.066310e+05            NaN           NaN
# West Bank and Gaza              4.685306e+06            NaN           NaN
# Yemen, Rep.                     2.916192e+07   2.258108e+10    774.334490
# Zambia                          1.786103e+07   2.330977e+10   1305.063254
# Zimbabwe                        1.464547e+07   2.144076e+10   1463.985910
#
#                                  life_exp  diabetes_percent  co2_per_cap  \
# Country
# Arab World                      71.806825         12.536001     4.712845
# Caribbean small states          73.637109         11.629346     8.490807
# Central Europe and the Baltics  76.976845          6.296002     6.377623
# Early-demographic dividend      70.483191         10.090910     2.345693
# East Asia & Pacific             76.068336          8.202608     6.071789
# ...                                   ...               ...          ...
# Virgin Islands (U.S.)           79.568293         12.300000          NaN
# West Bank and Gaza              73.895000          9.500000     0.740607
# Yemen, Rep.                     66.096000          5.400000     0.390480
# Zambia                          63.510000          4.500000     0.314183
# Zimbabwe                        61.195000          1.800000     0.782777
#
#                                 teacher      unemp  educat_expen  rural_pop  \
# Country
# Arab World                          NaN  10.191472           NaN  40.798353
# Caribbean small states              NaN   8.092527       5.16919  48.630009
# Central Europe and the Baltics      NaN   3.641848           NaN  37.561644
# Early-demographic dividend          NaN   5.844164           NaN  54.459204
# East Asia & Pacific                 NaN   3.897888           NaN  40.113467
# ...                                 ...        ...           ...        ...
# Virgin Islands (U.S.)               NaN   8.759000           NaN   4.168000
# West Bank and Gaza                  NaN  26.098000           NaN  23.560000
# Yemen, Rep.                         NaN  12.830000           NaN  62.727000
# Zambia                              NaN  11.412000           NaN  55.928000
# Zimbabwe                            NaN   4.991000           NaN  67.790000
#
#                                 renewable_percent  airplution
# Country
# Arab World                               4.094037  100.000000
# Caribbean small states                   8.825977   99.998738
# Central Europe and the Baltics          17.121893   97.949799
# Early-demographic dividend              25.554845   99.353070
# East Asia & Pacific                     13.857603   96.877523
# ...                                           ...         ...
# Virgin Islands (U.S.)                    3.877525   40.000000
# West Bank and Gaza                      10.472715  100.000000
# Yemen, Rep.                              2.276417  100.000000
# Zambia                                  87.985452  100.000000
# Zimbabwe                                81.797809  100.000000
#
# [264 rows x 12 columns]

# %%
df.drop(["teacher","educat_expen"], axis=1, inplace=True)

# %%
df.set_index('Country')
# Out:
#                                   population  GDP_in_Dollar   gdp_per_cap  \
# Country
# Arab World                      4.278703e+08   2.817415e+12   6584.740241
# Caribbean small states          7.401383e+06   7.772171e+10  10500.971902
# Central Europe and the Baltics  1.023786e+08   1.668852e+12  16300.792072
# Early-demographic dividend      3.290291e+09   1.198987e+13   3644.014598
# East Asia & Pacific             2.340628e+09   2.698777e+13  11530.138135
# ...                                      ...            ...           ...
# Virgin Islands (U.S.)           1.066310e+05            NaN           NaN
# West Bank and Gaza              4.685306e+06            NaN           NaN
# Yemen, Rep.                     2.916192e+07   2.258108e+10    774.334490
# Zambia                          1.786103e+07   2.330977e+10   1305.063254
# Zimbabwe                        1.464547e+07   2.144076e+10   1463.985910
#
#                                  life_exp  diabetes_percent  co2_per_cap  \
# Country
# Arab World                      71.806825         12.536001     4.712845
# Caribbean small states          73.637109         11.629346     8.490807
# Central Europe and the Baltics  76.976845          6.296002     6.377623
# Early-demographic dividend      70.483191         10.090910     2.345693
# East Asia & Pacific             76.068336          8.202608     6.071789
# ...                                   ...               ...          ...
# Virgin Islands (U.S.)           79.568293         12.300000          NaN
# West Bank and Gaza              73.895000          9.500000     0.740607
# Yemen, Rep.                     66.096000          5.400000     0.390480
# Zambia                          63.510000          4.500000     0.314183
# Zimbabwe                        61.195000          1.800000     0.782777
#
#                                     unemp  rural_pop  renewable_percent  \
# Country
# Arab World                      10.191472  40.798353           4.094037
# Caribbean small states           8.092527  48.630009           8.825977
# Central Europe and the Baltics   3.641848  37.561644          17.121893
# Early-demographic dividend       5.844164  54.459204          25.554845
# East Asia & Pacific              3.897888  40.113467          13.857603
# ...                                   ...        ...                ...
# Virgin Islands (U.S.)            8.759000   4.168000           3.877525
# West Bank and Gaza              26.098000  23.560000          10.472715
# Yemen, Rep.                     12.830000  62.727000           2.276417
# Zambia                          11.412000  55.928000          87.985452
# Zimbabwe                         4.991000  67.790000          81.797809
#
#                                 airplution
# Country
# Arab World                      100.000000
# Caribbean small states           99.998738
# Central Europe and the Baltics   97.949799
# Early-demographic dividend       99.353070
# East Asia & Pacific              96.877523
# ...                                    ...
# Virgin Islands (U.S.)            40.000000
# West Bank and Gaza              100.000000
# Yemen, Rep.                     100.000000
# Zambia                          100.000000
# Zimbabwe                        100.000000
#
# [264 rows x 10 columns]

# %%
df.dropna(axis=0, how='any',inplace=True)
df
# Out:
#                             Country    population  GDP_in_Dollar  \
# 0                        Arab World  4.278703e+08   2.817415e+12
# 1            Caribbean small states  7.401383e+06   7.772171e+10
# 2    Central Europe and the Baltics  1.023786e+08   1.668852e+12
# 3        Early-demographic dividend  3.290291e+09   1.198987e+13
# 4               East Asia & Pacific  2.340628e+09   2.698777e+13
# ..                              ...           ...            ...
# 256                         Vanuatu  2.998820e+05   9.342400e+08
# 258                         Vietnam  9.646211e+07   2.619212e+11
# 261                     Yemen, Rep.  2.916192e+07   2.258108e+10
# 262                          Zambia  1.786103e+07   2.330977e+10
# 263                        Zimbabwe  1.464547e+07   2.144076e+10
#
#       gdp_per_cap   life_exp  diabetes_percent  co2_per_cap      unemp  \
# 0     6584.740241  71.806825         12.536001     4.712845  10.191472
# 1    10500.971902  73.637109         11.629346     8.490807   8.092527
# 2    16300.792072  76.976845          6.296002     6.377623   3.641848
# 3     3644.014598  70.483191         10.090910     2.345693   5.844164
# 4    11530.138135  76.068336          8.202608     6.071789   3.897888
# ..            ...        ...               ...          ...        ...
# 256   3115.358620  70.323000         11.900000     0.527000   4.408000
# 258   2715.276036  75.317000          6.000000     2.057566   2.022000
# 261    774.334490  66.096000          5.400000     0.390480  12.830000
# 262   1305.063254  63.510000          4.500000     0.314183  11.412000
# 263   1463.985910  61.195000          1.800000     0.782777   4.991000
#
#      rural_pop  renewable_percent  airplution
# 0    40.798353           4.094037  100.000000
# 1    48.630009           8.825977   99.998738
# 2    37.561644          17.121893   97.949799
# 3    54.459204          25.554845   99.353070
# 4    40.113467          13.857603   96.877523
# ..         ...                ...         ...
# 256  74.606000          36.111065  100.000000
# 258  63.372000          34.998570  100.000000
# 261  62.727000           2.276417  100.000000
# 262  55.928000          87.985452  100.000000
# 263  67.790000          81.797809  100.000000
#
# [210 rows x 11 columns]

# %%
df.set_index('Country')
# Out:
#                                   population  GDP_in_Dollar   gdp_per_cap  \
# Country
# Arab World                      4.278703e+08   2.817415e+12   6584.740241
# Caribbean small states          7.401383e+06   7.772171e+10  10500.971902
# Central Europe and the Baltics  1.023786e+08   1.668852e+12  16300.792072
# Early-demographic dividend      3.290291e+09   1.198987e+13   3644.014598
# East Asia & Pacific             2.340628e+09   2.698777e+13  11530.138135
# ...                                      ...            ...           ...
# Vanuatu                         2.998820e+05   9.342400e+08   3115.358620
# Vietnam                         9.646211e+07   2.619212e+11   2715.276036
# Yemen, Rep.                     2.916192e+07   2.258108e+10    774.334490
# Zambia                          1.786103e+07   2.330977e+10   1305.063254
# Zimbabwe                        1.464547e+07   2.144076e+10   1463.985910
#
#                                  life_exp  diabetes_percent  co2_per_cap  \
# Country
# Arab World                      71.806825         12.536001     4.712845
# Caribbean small states          73.637109         11.629346     8.490807
# Central Europe and the Baltics  76.976845          6.296002     6.377623
# Early-demographic dividend      70.483191         10.090910     2.345693
# East Asia & Pacific             76.068336          8.202608     6.071789
# ...                                   ...               ...          ...
# Vanuatu                         70.323000         11.900000     0.527000
# Vietnam                         75.317000          6.000000     2.057566
# Yemen, Rep.                     66.096000          5.400000     0.390480
# Zambia                          63.510000          4.500000     0.314183
# Zimbabwe                        61.195000          1.800000     0.782777
#
#                                     unemp  rural_pop  renewable_percent  \
# Country
# Arab World                      10.191472  40.798353           4.094037
# Caribbean small states           8.092527  48.630009           8.825977
# Central Europe and the Baltics   3.641848  37.561644          17.121893
# Early-demographic dividend       5.844164  54.459204          25.554845
# East Asia & Pacific              3.897888  40.113467          13.857603
# ...                                   ...        ...                ...
# Vanuatu                          4.408000  74.606000          36.111065
# Vietnam                          2.022000  63.372000          34.998570
# Yemen, Rep.                     12.830000  62.727000           2.276417
# Zambia                          11.412000  55.928000          87.985452
# Zimbabwe                         4.991000  67.790000          81.797809
#
#                                 airplution
# Country
# Arab World                      100.000000
# Caribbean small states           99.998738
# Central Europe and the Baltics   97.949799
# Early-demographic dividend       99.353070
# East Asia & Pacific              96.877523
# ...                                    ...
# Vanuatu                         100.000000
# Vietnam                         100.000000
# Yemen, Rep.                     100.000000
# Zambia                          100.000000
# Zimbabwe                        100.000000
#
# [210 rows x 10 columns]

# %%
df.head(50)
# Out:
#                                               Country    population  \
# 0                                          Arab World  4.278703e+08
# 1                              Caribbean small states  7.401383e+06
# 2                      Central Europe and the Baltics  1.023786e+08
# 3                          Early-demographic dividend  3.290291e+09
# 4                                 East Asia & Pacific  2.340628e+09
# 5         East Asia & Pacific (excluding high income)  2.093675e+09
# 6          East Asia & Pacific (IDA & IBRD countries)  2.067984e+09
# 7                                           Euro area  3.425977e+08
# 8                               Europe & Central Asia  9.211401e+08
# 9       Europe & Central Asia (excluding high income)  3.994046e+08
# 10       Europe & Central Asia (IDA & IBRD countries)  4.607995e+08
# 11                                     European Union  4.475120e+08
# 12           Fragile and conflict affected situations  7.981386e+08
# 13             Heavily indebted poor countries (HIPC)  8.017080e+08
# 14                                        High income  1.235853e+09
# 15                                          IBRD only  4.816236e+09
# 16                                   IDA & IBRD total  6.486935e+09
# 17                                          IDA blend  5.615722e+08
# 18                                           IDA only  1.109127e+09
# 19                                          IDA total  1.670699e+09
# 20                          Late-demographic dividend  2.298471e+09
# 21                          Latin America & Caribbean  6.464308e+08
# 22  Latin America & Caribbean (excluding high income)  6.137731e+08
# 23  Latin America & the Caribbean (IDA & IBRD coun...  6.306448e+08
# 24       Least developed countries: UN classification  1.033389e+09
# 25                                Low & middle income  6.437681e+09
# 26                                         Low income  6.684550e+08
# 27                                Lower middle income  2.913363e+09
# 28                         Middle East & North Africa  4.567074e+08
# 31                                      Middle income  5.769226e+09
# 32                                      North America  3.658927e+08
# 34                                       OECD members  1.359964e+09
# 35                                 Other small states  3.136041e+07
# 36                        Pacific island small states  2.493696e+06
# 37                          Post-demographic dividend  1.112914e+09
# 38                           Pre-demographic dividend  9.449027e+08
# 39                                       Small states  4.125549e+07
# 40                                         South Asia  1.835777e+09
# 41                            South Asia (IDA & IBRD)  1.835777e+09
# 42                                 Sub-Saharan Africa  1.106958e+09
# 43         Sub-Saharan Africa (excluding high income)  1.105595e+09
# 44          Sub-Saharan Africa (IDA & IBRD countries)  1.106958e+09
# 45                                Upper middle income  2.855863e+09
# 46                                              World  7.673534e+09
# 47                                        Afghanistan  3.804175e+07
# 48                                            Albania  2.854191e+06
# 49                                            Algeria  4.305305e+07
# 52                                             Angola  3.182530e+07
# 54                                          Argentina  4.493871e+07
# 55                                            Armenia  2.957731e+06
#
#     GDP_in_Dollar   gdp_per_cap   life_exp  diabetes_percent  co2_per_cap  \
# 0    2.817415e+12   6584.740241  71.806825         12.536001     4.712845
# 1    7.772171e+10  10500.971902  73.637109         11.629346     8.490807
# 2    1.668852e+12  16300.792072  76.976845          6.296002     6.377623
# 3    1.198987e+13   3644.014598  70.483191         10.090910     2.345693
# 4    2.698777e+13  11530.138135  76.068336          8.202608     6.071789
# 5    1.721478e+13   8222.276873  75.210512          8.488062     5.562986
# 6    1.718189e+13   8308.522906  75.249229          8.514102     5.618534
# 7    1.335606e+13  38984.685990  82.059617          6.760327     6.545140
# 8    2.279282e+13  24744.140288  77.908607          6.686969     6.882182
# 9    3.248462e+12   8133.260847  73.590782          7.231416     7.583597
# 10   4.155157e+12   9017.278287  74.037603          7.099095     7.400544
# 11   1.562645e+13  34918.498375  81.034409          6.670720     6.468462
# 12   1.778456e+12   2228.255245  61.500000          6.478645     0.988604
# 13   7.830618e+11    976.741809  63.135006          5.729319     0.276852
# 14   5.514063e+13  44617.476531  80.656105          7.931788    10.392930
# 15   3.160411e+13   6561.994287  73.404877          9.301977     4.418627
# 16   3.391723e+13   5228.544142  71.071738          8.986860     3.453639
# 17   9.915475e+11   1765.663465  62.161750         10.604741     0.887013
# 18   1.331971e+12   1200.918607  65.304092          6.457722     0.379889
# 19   2.320314e+12   1388.828141  64.247800          7.851218     0.551236
# 20   2.298353e+13   9999.488420  76.224444          8.830938     6.491767
# 21   5.733774e+12   8869.894814  75.440948          9.694271     2.922612
# 22   5.149595e+12   8390.062921  75.246114          9.728371     2.778044
# 23   5.487957e+12   8702.137464  75.357415          9.671067     2.901515
# 24   1.115238e+12   1079.204614  65.039624          6.442058     0.341969
# 25   3.270907e+13   5080.877694  70.998819          9.006523     3.403971
# 26   5.415119e+11    810.094853  63.496339          6.393279     0.271830
# 27   6.334933e+12   2174.439797  68.422469          9.513246     1.515452
# 28   3.649608e+12   7991.129005  74.088909         11.373898     6.016492
# 31   3.215331e+13   5573.244107  71.854626          9.243898     3.749707
# 32   2.317714e+13  63344.077519  78.886891         10.461438    15.459681
# 34   5.369937e+13  39485.894203  80.077530          8.316848     8.980733
# 35   4.320929e+11  13778.293514  68.546932          8.241773     7.041731
# 36   1.063478e+10   4264.667414  69.929058         15.325311     1.411030
# 37   5.076992e+13  45618.886157  80.659892          7.578978     9.938830
# 38   1.403794e+12   1485.649585  60.820956          5.371280     0.580671
# 39   5.204572e+11  12615.465850  69.541132          9.268451     6.969563
# 40   3.591837e+12   1956.575921  69.412248         11.237926     1.545260
# 41   3.591837e+12   1956.575921  69.412248         11.237926     1.545260
# 42   1.766941e+12   1596.213734  61.273015          5.359440     0.834313
# 43   1.751180e+12   1583.926065  61.256533          5.331306     0.830603
# 44   1.766941e+12   1596.213734  61.273015          5.359440     0.834313
# 45   2.580776e+13   9036.765255  75.328985          9.001428     5.979792
# 46   8.779853e+13  11441.732865  72.563282          8.812044     0.004849
# 47   1.929110e+10    507.103432  64.486000          9.200000     0.245101
# 48   1.527918e+10   5353.244856  78.458000          9.000000     1.577163
# 49   1.710913e+11   3973.964072  76.693000          6.700000     3.699156
# 52   8.881570e+10   2790.726615  60.782000          4.500000     1.202861
# 54   4.454452e+11   9912.281809  76.520000          5.900000     4.619085
# 55   1.367280e+10   4622.733493  74.945000          6.100000     1.755976
#
#         unemp  rural_pop  renewable_percent  airplution
# 0   10.191472  40.798353           4.094037  100.000000
# 1    8.092527  48.630009           8.825977   99.998738
# 2    3.641848  37.561644          17.121893   97.949799
# 3    5.844164  54.459204          25.554845   99.353070
# 4    3.897888  40.113467          13.857603   96.877523
# 5    3.951413  43.429996          15.861236   99.092879
# 6    3.969032  43.499398          15.838521   99.081561
# 7    7.254748  22.782314          16.083262   77.369321
# 8    6.631572  27.590851          13.073085   85.056012
# 9    7.376411  32.181242           5.922013   96.297561
# 10   6.860255  33.497912           7.148184   96.709180
# 11   6.445280  25.270479          17.588451   79.863462
# 12   6.994557  55.049931          62.349184   99.997306
# 13   4.477225  63.518719          77.239910   99.998947
# 14   4.811218  18.952560          11.261103   56.132213
# 15   5.801745  44.383728          17.393440   97.402947
# 16   5.552639  49.051230          22.875958   98.043420
# 17   5.425470  57.292814          63.997265   99.971817
# 18   4.410048  65.172447          69.741939   99.937059
# 19   4.720010  62.521018          66.961440   99.948781
# 20   5.084845  36.706850          14.201816   95.015141
# 21   8.141540  19.129442          27.602500   87.198255
# 22   8.208613  19.300882          27.913628   87.777046
# 23   8.244177  19.105650          27.874359   87.406965
# 24   4.363387  65.898649          73.219505   99.999947
# 25   5.553212  49.150171          22.970535   98.102511
# 26   4.913977  66.681734          76.243603  100.000000
# 27   5.132245  60.314149          40.551513   99.443513
# 28   9.636612  34.321385           1.557857  100.000000
# 31   5.619501  47.118234          21.217440   97.890372
# 32   4.033488  17.638306          10.176186    3.022376
# 34   5.365522  19.195427          12.095780   60.634060
# 35   9.214163  37.403497          27.139747   91.544650
# 36   2.943942  60.961609          30.407900   93.629896
# 37   5.030064  18.534273          11.799662   52.805797
# 38   5.679897  58.223546          75.582589  100.000000
# 39   8.702975  40.841549          24.171181   93.213858
# 40   5.140203  65.568103          38.275385   99.320900
# 41   5.140203  65.568103          38.275385   99.320900
# 42   6.175757  59.287221          70.127375  100.000000
# 43   6.175041  59.288731          70.253931  100.000000
# 44   6.175757  59.287221          70.127375  100.000000
# 45   5.995347  33.648167          14.397640   96.328689
# 46   5.420153  44.285715          18.053755   91.295562
# 47  11.164000  74.246000          18.423477  100.000000
# 48  12.813000  38.771000          38.615210  100.000000
# 49  11.525000  26.811000           0.058959  100.000000
# 52   6.774000  33.823000          49.568210  100.000000
# 54  10.436000   8.009000          10.040078   93.852825
# 55  16.625000  36.781000          15.792004  100.000000

# %%
df_cleaned = df.iloc[44:]
df_cleaned
# Out:
#          Country  population  GDP_in_Dollar  gdp_per_cap  life_exp  \
# 47   Afghanistan  38041754.0   1.929110e+10   507.103432    64.486
# 48       Albania   2854191.0   1.527918e+10  5353.244856    78.458
# 49       Algeria  43053054.0   1.710913e+11  3973.964072    76.693
# 52        Angola  31825295.0   8.881570e+10  2790.726615    60.782
# 54     Argentina  44938712.0   4.454452e+11  9912.281809    76.520
# ..           ...         ...            ...          ...       ...
# 256      Vanuatu    299882.0   9.342400e+08  3115.358620    70.323
# 258      Vietnam  96462106.0   2.619212e+11  2715.276036    75.317
# 261  Yemen, Rep.  29161922.0   2.258108e+10   774.334490    66.096
# 262       Zambia  17861030.0   2.330977e+10  1305.063254    63.510
# 263     Zimbabwe  14645468.0   2.144076e+10  1463.985910    61.195
#
#      diabetes_percent  co2_per_cap   unemp  rural_pop  renewable_percent  \
# 47                9.2     0.245101  11.164     74.246          18.423477
# 48                9.0     1.577163  12.813     38.771          38.615210
# 49                6.7     3.699156  11.525     26.811           0.058959
# 52                4.5     1.202861   6.774     33.823          49.568210
# 54                5.9     4.619085  10.436      8.009          10.040078
# ..                ...          ...     ...        ...                ...
# 256              11.9     0.527000   4.408     74.606          36.111065
# 258               6.0     2.057566   2.022     63.372          34.998570
# 261               5.4     0.390480  12.830     62.727           2.276417
# 262               4.5     0.314183  11.412     55.928          87.985452
# 263               1.8     0.782777   4.991     67.790          81.797809
#
#      airplution
# 47   100.000000
# 48   100.000000
# 49   100.000000
# 52   100.000000
# 54    93.852825
# ..          ...
# 256  100.000000
# 258  100.000000
# 261  100.000000
# 262  100.000000
# 263  100.000000
#
# [166 rows x 11 columns]

# %%
df_corr = pd.DataFrame(df_cleaned,columns=['population','GDP_in_Dollar',"gdp_per_cap","life_exp","diabetes_percent","co2_per_cap","unemp","rural_pop","renewable_percent","airplution"]).corr()
df_corr
# Out:
#                    population  GDP_in_Dollar  gdp_per_cap  life_exp  \
# population           1.000000       0.574248    -0.043606  0.003481
# GDP_in_Dollar        0.574248       1.000000     0.250437  0.177344
# gdp_per_cap         -0.043606       0.250437     1.000000  0.647253
# life_exp             0.003481       0.177344     0.647253  1.000000
# diabetes_percent     0.078807       0.072423     0.021952  0.276249
# co2_per_cap          0.002503       0.204171     0.577015  0.468163
# unemp               -0.075626      -0.092654    -0.165030 -0.053378
# rural_pop            0.046799      -0.158726    -0.583157 -0.603431
# renewable_percent   -0.030021      -0.155241    -0.339733 -0.624216
# airplution           0.021502      -0.234851    -0.590240 -0.427901
#
#                    diabetes_percent  co2_per_cap     unemp  rural_pop  \
# population                 0.078807     0.002503 -0.075626   0.046799
# GDP_in_Dollar              0.072423     0.204171 -0.092654  -0.158726
# gdp_per_cap                0.021952     0.577015 -0.165030  -0.583157
# life_exp                   0.276249     0.468163 -0.053378  -0.603431
# diabetes_percent           1.000000     0.293922  0.029620  -0.044166
# co2_per_cap                0.293922     1.000000 -0.141753  -0.528946
# unemp                      0.029620    -0.141753  1.000000  -0.086823
# rural_pop                 -0.044166    -0.528946 -0.086823   1.000000
# renewable_percent         -0.379581    -0.523192 -0.173036   0.529315
# airplution                 0.046327    -0.264972  0.085875   0.308287
#
#                    renewable_percent  airplution
# population                 -0.030021    0.021502
# GDP_in_Dollar              -0.155241   -0.234851
# gdp_per_cap                -0.339733   -0.590240
# life_exp                   -0.624216   -0.427901
# diabetes_percent           -0.379581    0.046327
# co2_per_cap                -0.523192   -0.264972
# unemp                      -0.173036    0.085875
# rural_pop                   0.529315    0.308287
# renewable_percent           1.000000    0.076157
# airplution                  0.076157    1.000000

# %%
#corr = df.drop(['GDP','Population_in_mil'],axis=1).corr() #correlation matix ohne gsd und ohne population
f, ax = plt.subplots(figsize=(15, 15)) 
mask = np.triu(np.ones_like(df_corr, dtype=bool)) # removing the other side of the heatmap 
cmap = sns.diverging_palette(230, 20, as_cmap=True) 
#preparing cmap 
sns.heatmap(df_corr,mask=mask,cmap=cmap,linewidths=.5,square=True,annot=True) 
plt.show()

# %%
df_final = df_cleaned.set_index('Country')
df_final
# Out:
#              population  GDP_in_Dollar  gdp_per_cap  life_exp  \
# Country
# Afghanistan  38041754.0   1.929110e+10   507.103432    64.486
# Albania       2854191.0   1.527918e+10  5353.244856    78.458
# Algeria      43053054.0   1.710913e+11  3973.964072    76.693
# Angola       31825295.0   8.881570e+10  2790.726615    60.782
# Argentina    44938712.0   4.454452e+11  9912.281809    76.520
# ...                 ...            ...          ...       ...
# Vanuatu        299882.0   9.342400e+08  3115.358620    70.323
# Vietnam      96462106.0   2.619212e+11  2715.276036    75.317
# Yemen, Rep.  29161922.0   2.258108e+10   774.334490    66.096
# Zambia       17861030.0   2.330977e+10  1305.063254    63.510
# Zimbabwe     14645468.0   2.144076e+10  1463.985910    61.195
#
#              diabetes_percent  co2_per_cap   unemp  rural_pop  \
# Country
# Afghanistan               9.2     0.245101  11.164     74.246
# Albania                   9.0     1.577163  12.813     38.771
# Algeria                   6.7     3.699156  11.525     26.811
# Angola                    4.5     1.202861   6.774     33.823
# Argentina                 5.9     4.619085  10.436      8.009
# ...                       ...          ...     ...        ...
# Vanuatu                  11.9     0.527000   4.408     74.606
# Vietnam                   6.0     2.057566   2.022     63.372
# Yemen, Rep.               5.4     0.390480  12.830     62.727
# Zambia                    4.5     0.314183  11.412     55.928
# Zimbabwe                  1.8     0.782777   4.991     67.790
#
#              renewable_percent  airplution
# Country
# Afghanistan          18.423477  100.000000
# Albania              38.615210  100.000000
# Algeria               0.058959  100.000000
# Angola               49.568210  100.000000
# Argentina            10.040078   93.852825
# ...                        ...         ...
# Vanuatu              36.111065  100.000000
# Vietnam              34.998570  100.000000
# Yemen, Rep.           2.276417  100.000000
# Zambia               87.985452  100.000000
# Zimbabwe             81.797809  100.000000
#
# [166 rows x 10 columns]

# %%
X = df_final

# %% [markdown]
# ### Standardizing numeric features

# %%
from sklearn.preprocessing import StandardScaler # makes mean ~ 0 and Std ~ 1 (but does not necessarily create normal distribution!!)
X_prep = StandardScaler().fit_transform(X)

# Now, all features will have the same weight.
pd.DataFrame(X_prep, columns = X.columns).head()
pd.DataFrame(X_prep).describe()
#looking good
# Out:
#                   0             1             2             3             4  \
# count  1.660000e+02  1.660000e+02  1.660000e+02  1.660000e+02  1.660000e+02
# mean   2.574915e-17 -3.344045e-18  4.949187e-17 -4.012854e-17  3.183531e-16
# std    1.003026e+00  1.003026e+00  1.003026e+00  1.003026e+00  1.003026e+00
# min   -2.800738e-01 -2.345672e-01 -7.030135e-01 -2.587455e+00 -1.685852e+00
# 25%   -2.627770e-01 -2.284534e-01 -6.190787e-01 -7.352642e-01 -6.340646e-01
# 50%   -2.190587e-01 -2.123740e-01 -4.245554e-01  2.085579e-01 -2.665728e-01
# 75%   -8.550588e-02 -1.135212e-01  1.228976e-01  7.059892e-01  4.747469e-01
# max    8.694397e+00  1.013824e+01  5.083283e+00  1.590663e+00  3.636444e+00
#
#                   5             6             7           8             9
# count  1.660000e+02  1.660000e+02  1.660000e+02  166.000000  1.660000e+02
# mean   5.016068e-17  6.119603e-17  8.828279e-17    0.000000 -7.356900e-18
# std    1.003026e+00  1.003026e+00  1.003026e+00    1.003026  1.003026e+00
# min   -7.580923e-01 -1.303270e+00 -1.815584e+00   -1.197510 -3.288459e+00
# 25%   -6.485794e-01 -6.691044e-01 -8.435532e-01   -0.871356  3.707764e-01
# 50%   -3.211575e-01 -3.231393e-01 -4.960802e-03   -0.276767  4.015330e-01
# 75%    2.355270e-01  4.242546e-01  7.548749e-01    0.672649  4.015330e-01
# max    5.943533e+00  4.141473e+00  2.006062e+00    2.197507  4.015330e-01

# %%
df_standardized = pd.DataFrame(X_prep)
df_standardized
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.036467 -0.225433 -0.690583 -1.033464  0.392378 -0.720261  0.821704
# 1   -0.262417 -0.227375 -0.445560  0.825312  0.341690 -0.490633  1.137900
# 2   -0.004288 -0.151967 -0.515297  0.590504 -0.241229 -0.124832  0.890926
# 3   -0.076385 -0.191786 -0.575122 -1.526228 -0.798802 -0.555157 -0.020078
# 4    0.007820 -0.019188 -0.215054  0.567488 -0.443983  0.033750  0.682110
# ..        ...       ...       ...       ...       ...       ...       ...
# 161 -0.278819 -0.234318 -0.558709 -0.256934  1.076673 -0.671666 -0.473759
# 162  0.338667 -0.108008 -0.578937  0.407446 -0.418638 -0.407819 -0.931275
# 163 -0.093487 -0.223841 -0.677072 -0.819276 -0.570704 -0.695200  1.141160
# 164 -0.166054 -0.223489 -0.650238 -1.163307 -0.798802 -0.708353  0.869258
# 165 -0.186702 -0.224393 -0.642203 -1.471285 -1.483097 -0.627574 -0.361969
#
#             7         8         9
# 0    1.455216 -0.544728  0.401533
# 1   -0.107584  0.170706  0.401533
# 2   -0.634464 -1.195421  0.401533
# 3   -0.325561  0.558793  0.401533
# 4   -1.462759 -0.841769  0.174703
# ..        ...       ...       ...
# 161  1.471076  0.081979  0.401533
# 162  0.976178  0.042561  0.401533
# 163  0.947763 -1.116851  0.401533
# 164  0.648243  1.919994  0.401533
# 165  1.170807  1.700753  0.401533
#
# [166 rows x 10 columns]

# %%
X_prep = df_standardized

# %% [markdown]
# ### K-means

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3, random_state = 1234)
model.fit_predict(df_standardized)

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state = 1234)
kmeans.fit(X_prep)
# Out:
# KMeans(random_state=1234)

# %%
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([6, 5, 5, 1, 0, 5, 4, 0, 0, 0, 2, 6, 6, 0, 0, 6, 1, 6, 0, 5, 5, 5,
#        4, 0, 1, 1, 5, 1, 1, 4, 1, 1, 0, 3, 5, 6, 1, 1, 5, 1, 0, 0, 0, 4,
#        5, 0, 0, 6, 0, 5, 4, 1, 1, 6, 4, 5, 1, 5, 0, 1, 5, 6, 1, 1, 6, 1,
#        6, 0, 4, 3, 6, 5, 4, 0, 6, 0, 5, 0, 1, 0, 2, 6, 1, 0, 0, 1, 1, 5,
#        0, 4, 1, 1, 0, 4, 1, 0, 5, 6, 0, 6, 0, 5, 5, 1, 1, 5, 1, 0, 4, 6,
#        1, 1, 5, 4, 0, 6, 0, 6, 6, 0, 6, 0, 4, 2, 0, 0, 1, 6, 5, 2, 1, 5,
#        1, 0, 0, 0, 6, 5, 4, 6, 5, 5, 6, 4, 4, 6, 1, 0, 6, 1, 6, 2, 5, 5,
#        1, 5, 2, 0, 7, 4, 6, 6, 6, 5, 1, 1])

# %%
from sklearn.metrics import silhouette_score

K = range(2, 9)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))

print(list(K))
print(silhouette)

plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Score showing the optimal k')
# Out:
# [2, 3, 4, 5, 6, 7, 8]
# [0.28630094732418787, 0.2527833005265907, 0.2718699520289029, 0.27778968730163306, 0.2503667702425797, 0.27578787980971003, 0.2738530515880047]
# Text(0.5, 1.0, 'Silhouette Score showing the optimal k')

# %%
kmeans.inertia_
# Out:
# 494.6662625749676

# %%
K = range(1, 9)
print(list(K))
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

print(inertia)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1659.9999999999998, 1262.9979770840757, 1038.3653276910084, 825.3445187295221, 724.0360389250125, 647.6316803232176, 569.3949556618732, 494.6662625749676]
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %% [markdown]
# ### Kmeans with 5 clusters

# %%
model = KMeans(n_clusters=5)
clusters = model.fit_predict(X_prep)
print(silhouette_score(X_prep, clusters))
# Out:
# 0.2564031164884977

# %%
print(pd.Series(clusters).value_counts().sort_index())
# Out:
# 0    68
# 1    33
# 2    22
# 3    40
# 4     3
# dtype: int64

# %% [markdown]
# ### Kmeans with 7 clusters

# %%
model = KMeans(n_clusters=7)
clusters = model.fit_predict(X_prep)
print(silhouette_score(X_prep, clusters))
# Out:
# 0.280826408931768

# %%
print(pd.Series(clusters).value_counts().sort_index())
# Out:
# 0    29
# 1    46
# 2     3
# 3    17
# 4     6
# 5    36
# 6    29
# dtype: int64

# %% [markdown]
# ### Kmeans without GDP & Population

# %%
df_cleaned
# Out:
#          Country  gdp_per_cap  life_exp  diabetes_percent  co2_per_cap  \
# 47   Afghanistan   507.103432    64.486               9.2     0.245101
# 48       Albania  5353.244856    78.458               9.0     1.577163
# 49       Algeria  3973.964072    76.693               6.7     3.699156
# 52        Angola  2790.726615    60.782               4.5     1.202861
# 54     Argentina  9912.281809    76.520               5.9     4.619085
# ..           ...          ...       ...               ...          ...
# 256      Vanuatu  3115.358620    70.323              11.9     0.527000
# 258      Vietnam  2715.276036    75.317               6.0     2.057566
# 261  Yemen, Rep.   774.334490    66.096               5.4     0.390480
# 262       Zambia  1305.063254    63.510               4.5     0.314183
# 263     Zimbabwe  1463.985910    61.195               1.8     0.782777
#
#       unemp  rural_pop  renewable_percent  airplution
# 47   11.164     74.246          18.423477  100.000000
# 48   12.813     38.771          38.615210  100.000000
# 49   11.525     26.811           0.058959  100.000000
# 52    6.774     33.823          49.568210  100.000000
# 54   10.436      8.009          10.040078   93.852825
# ..      ...        ...                ...         ...
# 256   4.408     74.606          36.111065  100.000000
# 258   2.022     63.372          34.998570  100.000000
# 261  12.830     62.727           2.276417  100.000000
# 262  11.412     55.928          87.985452  100.000000
# 263   4.991     67.790          81.797809  100.000000
#
# [166 rows x 9 columns]

# %%
df_corr = pd.DataFrame(df_cleaned,columns=["gdp_per_cap","life_exp","diabetes_percent","co2_per_cap","unemp","rural_pop","renewable_percent","airplution"]).corr()
df_corr
# Out:
#                    gdp_per_cap  life_exp  diabetes_percent  co2_per_cap  \
# gdp_per_cap           1.000000  0.647253          0.021952     0.577015
# life_exp              0.647253  1.000000          0.276249     0.468163
# diabetes_percent      0.021952  0.276249          1.000000     0.293922
# co2_per_cap           0.577015  0.468163          0.293922     1.000000
# unemp                -0.165030 -0.053378          0.029620    -0.141753
# rural_pop            -0.583157 -0.603431         -0.044166    -0.528946
# renewable_percent    -0.339733 -0.624216         -0.379581    -0.523192
# airplution           -0.590240 -0.427901          0.046327    -0.264972
#
#                       unemp  rural_pop  renewable_percent  airplution
# gdp_per_cap       -0.165030  -0.583157          -0.339733   -0.590240
# life_exp          -0.053378  -0.603431          -0.624216   -0.427901
# diabetes_percent   0.029620  -0.044166          -0.379581    0.046327
# co2_per_cap       -0.141753  -0.528946          -0.523192   -0.264972
# unemp              1.000000  -0.086823          -0.173036    0.085875
# rural_pop         -0.086823   1.000000           0.529315    0.308287
# renewable_percent -0.173036   0.529315           1.000000    0.076157
# airplution         0.085875   0.308287           0.076157    1.000000

# %%
#corr = df.drop(['GDP','Population_in_mil'],axis=1).corr() #correlation matix ohne gsd und ohne population
f, ax = plt.subplots(figsize=(15, 15)) 
mask = np.triu(np.ones_like(df_corr, dtype=bool)) # removing the other side of the heatmap 
cmap = sns.diverging_palette(230, 20, as_cmap=True) 
#preparing cmap 
sns.heatmap(df_corr,mask=mask,cmap=cmap,linewidths=.5,square=True,annot=True) 
plt.show()

# %%
df_final_wo = df_cleaned
df_final_wo
# Out:
#          Country  gdp_per_cap  life_exp  diabetes_percent  co2_per_cap  \
# 47   Afghanistan   507.103432    64.486               9.2     0.245101
# 48       Albania  5353.244856    78.458               9.0     1.577163
# 49       Algeria  3973.964072    76.693               6.7     3.699156
# 52        Angola  2790.726615    60.782               4.5     1.202861
# 54     Argentina  9912.281809    76.520               5.9     4.619085
# ..           ...          ...       ...               ...          ...
# 256      Vanuatu  3115.358620    70.323              11.9     0.527000
# 258      Vietnam  2715.276036    75.317               6.0     2.057566
# 261  Yemen, Rep.   774.334490    66.096               5.4     0.390480
# 262       Zambia  1305.063254    63.510               4.5     0.314183
# 263     Zimbabwe  1463.985910    61.195               1.8     0.782777
#
#       unemp  rural_pop  renewable_percent  airplution
# 47   11.164     74.246          18.423477  100.000000
# 48   12.813     38.771          38.615210  100.000000
# 49   11.525     26.811           0.058959  100.000000
# 52    6.774     33.823          49.568210  100.000000
# 54   10.436      8.009          10.040078   93.852825
# ..      ...        ...                ...         ...
# 256   4.408     74.606          36.111065  100.000000
# 258   2.022     63.372          34.998570  100.000000
# 261  12.830     62.727           2.276417  100.000000
# 262  11.412     55.928          87.985452  100.000000
# 263   4.991     67.790          81.797809  100.000000
#
# [166 rows x 9 columns]

# %%
df_final_wo.drop(labels="Country", axis=1, inplace=True)
df_final_wo
# Out:
# C:\Users\broth\anaconda3\envs\kittycat\lib\site-packages\pandas\core\frame.py:4160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      gdp_per_cap  life_exp  diabetes_percent  co2_per_cap   unemp  rural_pop  \
# 47    507.103432    64.486               9.2     0.245101  11.164     74.246
# 48   5353.244856    78.458               9.0     1.577163  12.813     38.771
# 49   3973.964072    76.693               6.7     3.699156  11.525     26.811
# 52   2790.726615    60.782               4.5     1.202861   6.774     33.823
# 54   9912.281809    76.520               5.9     4.619085  10.436      8.009
# ..           ...       ...               ...          ...     ...        ...
# 256  3115.358620    70.323              11.9     0.527000   4.408     74.606
# 258  2715.276036    75.317               6.0     2.057566   2.022     63.372
# 261   774.334490    66.096               5.4     0.390480  12.830     62.727
# 262  1305.063254    63.510               4.5     0.314183  11.412     55.928
# 263  1463.985910    61.195               1.8     0.782777   4.991     67.790
#
#      renewable_percent  airplution
# 47           18.423477  100.000000
# 48           38.615210  100.000000
# 49            0.058959  100.000000
# 52           49.568210  100.000000
# 54           10.040078   93.852825
# ..                 ...         ...
# 256          36.111065  100.000000
# 258          34.998570  100.000000
# 261           2.276417  100.000000
# 262          87.985452  100.000000
# 263          81.797809  100.000000
#
# [166 rows x 8 columns]

# %%
X2= df_final_wo
X2
# Out:
#      gdp_per_cap  life_exp  diabetes_percent  co2_per_cap   unemp  rural_pop  \
# 47    507.103432    64.486               9.2     0.245101  11.164     74.246
# 48   5353.244856    78.458               9.0     1.577163  12.813     38.771
# 49   3973.964072    76.693               6.7     3.699156  11.525     26.811
# 52   2790.726615    60.782               4.5     1.202861   6.774     33.823
# 54   9912.281809    76.520               5.9     4.619085  10.436      8.009
# ..           ...       ...               ...          ...     ...        ...
# 256  3115.358620    70.323              11.9     0.527000   4.408     74.606
# 258  2715.276036    75.317               6.0     2.057566   2.022     63.372
# 261   774.334490    66.096               5.4     0.390480  12.830     62.727
# 262  1305.063254    63.510               4.5     0.314183  11.412     55.928
# 263  1463.985910    61.195               1.8     0.782777   4.991     67.790
#
#      renewable_percent  airplution
# 47           18.423477  100.000000
# 48           38.615210  100.000000
# 49            0.058959  100.000000
# 52           49.568210  100.000000
# 54           10.040078   93.852825
# ..                 ...         ...
# 256          36.111065  100.000000
# 258          34.998570  100.000000
# 261           2.276417  100.000000
# 262          87.985452  100.000000
# 263          81.797809  100.000000
#
# [166 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler # makes mean ~ 0 and Std ~ 1 (but does not necessarily create normal distribution!!)
X_prep2 = StandardScaler().fit_transform(X2)

# Now, all features will have the same weight.
pd.DataFrame(X_prep2, columns = X2.columns).head()
pd.DataFrame(X_prep2).describe()
#looking good
# Out:
#                   0             1             2             3             4  \
# count  1.660000e+02  1.660000e+02  1.660000e+02  1.660000e+02  1.660000e+02
# mean   4.949187e-17 -4.012854e-17  3.183531e-16  5.016068e-17  6.119603e-17
# std    1.003026e+00  1.003026e+00  1.003026e+00  1.003026e+00  1.003026e+00
# min   -7.030135e-01 -2.587455e+00 -1.685852e+00 -7.580923e-01 -1.303270e+00
# 25%   -6.190787e-01 -7.352642e-01 -6.340646e-01 -6.485794e-01 -6.691044e-01
# 50%   -4.245554e-01  2.085579e-01 -2.665728e-01 -3.211575e-01 -3.231393e-01
# 75%    1.228976e-01  7.059892e-01  4.747469e-01  2.355270e-01  4.242546e-01
# max    5.083283e+00  1.590663e+00  3.636444e+00  5.943533e+00  4.141473e+00
#
#                   5           6             7
# count  1.660000e+02  166.000000  1.660000e+02
# mean   8.828279e-17    0.000000 -7.356900e-18
# std    1.003026e+00    1.003026  1.003026e+00
# min   -1.815584e+00   -1.197510 -3.288459e+00
# 25%   -8.435532e-01   -0.871356  3.707764e-01
# 50%   -4.960802e-03   -0.276767  4.015330e-01
# 75%    7.548749e-01    0.672649  4.015330e-01
# max    2.006062e+00    2.197507  4.015330e-01

# %%
df_standardized2 = pd.DataFrame(X_prep2)
df_standardized2
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.690583 -1.033464  0.392378 -0.720261  0.821704  1.455216 -0.544728
# 1   -0.445560  0.825312  0.341690 -0.490633  1.137900 -0.107584  0.170706
# 2   -0.515297  0.590504 -0.241229 -0.124832  0.890926 -0.634464 -1.195421
# 3   -0.575122 -1.526228 -0.798802 -0.555157 -0.020078 -0.325561  0.558793
# 4   -0.215054  0.567488 -0.443983  0.033750  0.682110 -1.462759 -0.841769
# ..        ...       ...       ...       ...       ...       ...       ...
# 161 -0.558709 -0.256934  1.076673 -0.671666 -0.473759  1.471076  0.081979
# 162 -0.578937  0.407446 -0.418638 -0.407819 -0.931275  0.976178  0.042561
# 163 -0.677072 -0.819276 -0.570704 -0.695200  1.141160  0.947763 -1.116851
# 164 -0.650238 -1.163307 -0.798802 -0.708353  0.869258  0.648243  1.919994
# 165 -0.642203 -1.471285 -1.483097 -0.627574 -0.361969  1.170807  1.700753
#
#             7
# 0    0.401533
# 1    0.401533
# 2    0.401533
# 3    0.401533
# 4    0.174703
# ..        ...
# 161  0.401533
# 162  0.401533
# 163  0.401533
# 164  0.401533
# 165  0.401533
#
# [166 rows x 8 columns]

# %%
X_prep2 = df_standardized2

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3, random_state = 1234)
model.fit_predict(df_standardized2)

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state = 1234)
kmeans.fit(X_prep2)
# Out:
# KMeans(random_state=1234)

# %%
clusters2 = kmeans.predict(X_prep2)
clusters2
# Out:
# array([6, 4, 4, 1, 4, 4, 3, 7, 2, 4, 0, 6, 6, 2, 7, 6, 1, 1, 2, 4, 5, 4,
#        3, 2, 1, 1, 5, 1, 1, 3, 1, 1, 2, 2, 4, 6, 1, 1, 4, 1, 2, 2, 2, 7,
#        2, 2, 2, 6, 2, 2, 3, 5, 1, 6, 3, 5, 1, 4, 7, 1, 4, 6, 1, 1, 6, 5,
#        2, 2, 3, 6, 2, 4, 3, 7, 6, 7, 4, 2, 1, 7, 0, 2, 1, 2, 2, 5, 1, 4,
#        2, 7, 1, 1, 6, 3, 1, 7, 5, 6, 2, 2, 2, 4, 2, 1, 1, 5, 1, 7, 3, 6,
#        1, 1, 4, 3, 0, 6, 2, 6, 2, 2, 2, 2, 3, 0, 2, 2, 1, 6, 5, 0, 1, 4,
#        1, 7, 2, 2, 6, 5, 3, 6, 4, 4, 6, 3, 7, 5, 1, 2, 2, 1, 6, 0, 4, 4,
#        1, 2, 0, 7, 3, 3, 2, 6, 2, 5, 1, 1])

# %%
from sklearn.metrics import silhouette_score

K = range(2, 9)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep2)
    silhouette.append(silhouette_score(X_prep2, kmeans.predict(X_prep2)))

print(list(K))
print(silhouette)

plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Score showing the optimal k')
# Out:
# [2, 3, 4, 5, 6, 7, 8]
# [0.296103098765494, 0.2841367132288538, 0.28516918699776966, 0.26403714115261817, 0.2928901135204266, 0.287124972628144, 0.2842812035994023]
# Text(0.5, 1.0, 'Silhouette Score showing the optimal k')

# %%
model = KMeans(n_clusters=6)
clusters2 = model.fit_predict(X_prep2)
print(silhouette_score(X_prep2, clusters2))
# Out:
# 0.27874309823090204

# %%
print(pd.Series(clusters2).value_counts().sort_index())
# Out:
# 0    24
# 1    15
# 2    28
# 3    18
# 4    36
# 5    45
# dtype: int64

# %%
df_final_without_countries = df_cleaned
df_final_without_countries["cluster"] = clusters2
df_final_without_countries.head(20)
# Out:
# <ipython-input-138-02cdfca30f94>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_without_countries["cluster"] = clusters2
#      gdp_per_cap   life_exp  diabetes_percent  co2_per_cap   unemp  rural_pop  \
# 47    507.103432  64.486000               9.2     0.245101  11.164     74.246
# 48   5353.244856  78.458000               9.0     1.577163  12.813     38.771
# 49   3973.964072  76.693000               6.7     3.699156  11.525     26.811
# 52   2790.726615  60.782000               4.5     1.202861   6.774     33.823
# 54   9912.281809  76.520000               5.9     4.619085  10.436      8.009
# 55   4622.733493  74.945000               6.1     1.755976  16.625     36.781
# 57  55060.326101  82.748780               5.6    15.539220   5.328     13.876
# 58  50137.662776  81.692683               6.6     7.033336   4.779     41.485
# 59   4793.587020  72.864000               6.1     3.855347   5.960     43.969
# 60  34863.742098  73.752000               8.8     4.725278  11.270     16.868
# 61  23503.977127  77.163000              15.6    22.228981   0.763     10.606
# 62   1855.739824  72.320000               9.2     0.533299   4.151     62.595
# 63  18148.244926  79.081000              13.4     4.465129  10.938     68.842
# 64   6663.295293  74.175610               5.0     6.133708   4.625     20.956
# 65  46420.663767  81.595122               4.6     8.550513   5.692      1.959
# 66   4815.163711  74.496000              17.1     1.542847   6.357     54.134
# 67   1219.432672  61.470000               1.0     0.595648   2.023     52.139
# 69   3316.175714  71.460000              10.3     1.712274   2.390     58.388
# 70   3552.068760  71.239000               6.8     1.958514   3.450     30.227
# 71   6108.510696  77.262000               9.0     6.451938  18.438     51.374
#
#     renewable_percent  airplution  cluster
# 47          18.423477  100.000000        0
# 48          38.615210  100.000000        2
# 49           0.058959  100.000000        5
# 52          49.568210  100.000000        4
# 54          10.040078   93.852825        5
# 55          15.792004  100.000000        2
# 57           9.180503   24.893584        3
# 58          34.394992   85.051538        5
# 59           2.310758  100.000000        5
# 60           1.210513  100.000000        5
# 61           0.000000  100.000000        1
# 62          34.747069  100.000000        0
# 63           2.786358  100.000000        0
# 64           6.770870   99.931352        5
# 65           9.201641   91.948540        1
# 66          35.023630  100.000000        0
# 67          50.862618  100.000000        4
# 69          86.904548  100.000000        0
# 70          17.538182   99.999132        5
# 71          40.750060   99.955235        2

# %%
df_final_without_countries
# Out:
#      gdp_per_cap  life_exp  diabetes_percent  co2_per_cap   unemp  rural_pop  \
# 47    507.103432    64.486               9.2     0.245101  11.164     74.246
# 48   5353.244856    78.458               9.0     1.577163  12.813     38.771
# 49   3973.964072    76.693               6.7     3.699156  11.525     26.811
# 52   2790.726615    60.782               4.5     1.202861   6.774     33.823
# 54   9912.281809    76.520               5.9     4.619085  10.436      8.009
# ..           ...       ...               ...          ...     ...        ...
# 256  3115.358620    70.323              11.9     0.527000   4.408     74.606
# 258  2715.276036    75.317               6.0     2.057566   2.022     63.372
# 261   774.334490    66.096               5.4     0.390480  12.830     62.727
# 262  1305.063254    63.510               4.5     0.314183  11.412     55.928
# 263  1463.985910    61.195               1.8     0.782777   4.991     67.790
#
#      renewable_percent  airplution  cluster
# 47           18.423477  100.000000        0
# 48           38.615210  100.000000        2
# 49            0.058959  100.000000        5
# 52           49.568210  100.000000        4
# 54           10.040078   93.852825        5
# ..                 ...         ...      ...
# 256          36.111065  100.000000        0
# 258          34.998570  100.000000        5
# 261           2.276417  100.000000        2
# 262          87.985452  100.000000        4
# 263          81.797809  100.000000        4
#
# [166 rows x 9 columns]

# %%
df_countries= df.dropna(axis=0, how='any',inplace=True)
df_countries2 = df_countries = df.iloc[44:]
df_countries2
# Out:
#          Country  population  GDP_in_Dollar  gdp_per_cap  life_exp  \
# 47   Afghanistan  38041754.0   1.929110e+10   507.103432    64.486
# 48       Albania   2854191.0   1.527918e+10  5353.244856    78.458
# 49       Algeria  43053054.0   1.710913e+11  3973.964072    76.693
# 52        Angola  31825295.0   8.881570e+10  2790.726615    60.782
# 54     Argentina  44938712.0   4.454452e+11  9912.281809    76.520
# ..           ...         ...            ...          ...       ...
# 256      Vanuatu    299882.0   9.342400e+08  3115.358620    70.323
# 258      Vietnam  96462106.0   2.619212e+11  2715.276036    75.317
# 261  Yemen, Rep.  29161922.0   2.258108e+10   774.334490    66.096
# 262       Zambia  17861030.0   2.330977e+10  1305.063254    63.510
# 263     Zimbabwe  14645468.0   2.144076e+10  1463.985910    61.195
#
#      diabetes_percent  co2_per_cap   unemp  rural_pop  renewable_percent  \
# 47                9.2     0.245101  11.164     74.246          18.423477
# 48                9.0     1.577163  12.813     38.771          38.615210
# 49                6.7     3.699156  11.525     26.811           0.058959
# 52                4.5     1.202861   6.774     33.823          49.568210
# 54                5.9     4.619085  10.436      8.009          10.040078
# ..                ...          ...     ...        ...                ...
# 256              11.9     0.527000   4.408     74.606          36.111065
# 258               6.0     2.057566   2.022     63.372          34.998570
# 261               5.4     0.390480  12.830     62.727           2.276417
# 262               4.5     0.314183  11.412     55.928          87.985452
# 263               1.8     0.782777   4.991     67.790          81.797809
#
#      airplution
# 47   100.000000
# 48   100.000000
# 49   100.000000
# 52   100.000000
# 54    93.852825
# ..          ...
# 256  100.000000
# 258  100.000000
# 261  100.000000
# 262  100.000000
# 263  100.000000
#
# [166 rows x 11 columns]

# %%
df_cluster_6=pd.concat([df_countries2.Country.reset_index(drop=True),df_final_without_countries.reset_index(drop=True)],axis=1)
df_cluster_6
# Out:
#          Country  gdp_per_cap  life_exp  diabetes_percent  co2_per_cap  \
# 0    Afghanistan   507.103432    64.486               9.2     0.245101
# 1        Albania  5353.244856    78.458               9.0     1.577163
# 2        Algeria  3973.964072    76.693               6.7     3.699156
# 3         Angola  2790.726615    60.782               4.5     1.202861
# 4      Argentina  9912.281809    76.520               5.9     4.619085
# ..           ...          ...       ...               ...          ...
# 161      Vanuatu  3115.358620    70.323              11.9     0.527000
# 162      Vietnam  2715.276036    75.317               6.0     2.057566
# 163  Yemen, Rep.   774.334490    66.096               5.4     0.390480
# 164       Zambia  1305.063254    63.510               4.5     0.314183
# 165     Zimbabwe  1463.985910    61.195               1.8     0.782777
#
#       unemp  rural_pop  renewable_percent  airplution  cluster
# 0    11.164     74.246          18.423477  100.000000        0
# 1    12.813     38.771          38.615210  100.000000        2
# 2    11.525     26.811           0.058959  100.000000        5
# 3     6.774     33.823          49.568210  100.000000        4
# 4    10.436      8.009          10.040078   93.852825        5
# ..      ...        ...                ...         ...      ...
# 161   4.408     74.606          36.111065  100.000000        0
# 162   2.022     63.372          34.998570  100.000000        5
# 163  12.830     62.727           2.276417  100.000000        2
# 164  11.412     55.928          87.985452  100.000000        4
# 165   4.991     67.790          81.797809  100.000000        4
#
# [166 rows x 10 columns]

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world=world.rename(columns={'name':'Country'})

# %%
dic={'United States of America':'United States',
'Russia':'Russian Federation',
'South Korea': 'Korea, Rep.',
'Egypt': 'Egypt, Arab Rep.',
'Bosnia and Herz.':'Bosnia and Herzegovina',
'Central African Rep.':'Central African Republic',
"Côte d'Ivoire":"Cote d'Ivoire",
'Dem. Rep. Congo':'Congo, Dem. Rep.',
'Eq. Guinea':'Equatorial Guinea',
'Yemen':'Yemen, Rep.',
'Slovakia':'Slovak Republic',
'Kyrgyzstan':'Kyrgyz Republic'}

# %%
world.Country=world.Country.replace(dic)

# %%
world=world.merge(df_cluster_6[['Country','cluster']], on='Country', how='left')
world['cluster']=world['cluster']+1
world
# Out:
#        pop_est      continent              Country iso_a3  gdp_md_est  \
# 0       920938        Oceania                 Fiji    FJI      8374.0
# 1     53950935         Africa             Tanzania    TZA    150600.0
# 2       603253         Africa            W. Sahara    ESH       906.5
# 3     35623680  North America               Canada    CAN   1674000.0
# 4    326625791  North America        United States    USA  18560000.0
# ..         ...            ...                  ...    ...         ...
# 172    7111024         Europe               Serbia    SRB    101800.0
# 173     642550         Europe           Montenegro    MNE     10610.0
# 174    1895250         Europe               Kosovo    -99     18490.0
# 175    1218208  North America  Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa             S. Sudan    SSD     20880.0
#
#                                               geometry  cluster_x  cluster_y  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...        1.0        0.0
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...        1.0        4.0
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...        NaN        NaN
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...        1.0        3.0
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...        1.0        3.0
# ..                                                 ...        ...        ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...        1.0        2.0
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...        1.0        2.0
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...        NaN        NaN
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...        2.0        1.0
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...        NaN        NaN
#
#      cluster
# 0        1.0
# 1        5.0
# 2        NaN
# 3        4.0
# 4        4.0
# ..       ...
# 172      3.0
# 173      3.0
# 174      NaN
# 175      2.0
# 176      NaN
#
# [177 rows x 9 columns]

# %%
# Read world Countries

fig, ax = plt.subplots(figsize=(20,18))
world.plot(ax=ax, column='cluster',cmap='tab10')
#cities.plot(ax=ax, color='black', markersize=10, marker ='o')
#graticules.plot(ax=ax, color='lightgray', linewidth=0.5)
ax.set(xlabel='Longitude(Degrees)',ylabel='Latitude(Degrees)',title='4 CLUSTER MAP')
plt.show()

# %% [markdown]
# ### CPA
