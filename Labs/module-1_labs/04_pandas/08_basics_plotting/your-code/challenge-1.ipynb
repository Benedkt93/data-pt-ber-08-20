# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# #### Define your own data. We would like to have a variable called x which contains a list of numbers from 0 to 100. Furthermore, we would like a variables called y which is twice x, and a variable called z which is the square of x.

# %%
# your code here

x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes in a line plot.
#
# #### There are 2 ways of doing this - the way we have seen in class, and also using a subplot. Please research and try both!
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here - 1st way

plt.subplot(1,2,1) # (#rows, #columns, #position)
plt.plot(x,y,lw=3,color="b", ls='--')
plt.subplot(1,2,2)
plt.plot(x,z,lw=3, color="r",ls='-')

plt.show()

# %%
# your code here - 2nd way

fig,axes=plt.subplots(1,2)
axes[0].plot(x,y,color="b", lw=3, ls='--')
axes[1].plot(x,z,color="r", lw=3, ls='-')

plt.show()

# %% [markdown]
# #### Augmenting your previous code, label your axes.

# %%
# your code here

plt.subplot(1,2,1)
plt.plot(x,y,lw=3,color="b", ls='--')
plt.xlabel("x")
plt.ylabel("y")

plt.subplot(1,2,2)
plt.plot(x,z,lw=3, color="r",ls='-')
plt.xlabel("x")
plt.ylabel("z")

plt.subplots_adjust(right = 1.8) #add some space between subplots
plt.show()

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

plt.subplot(1, 2, 1)
plt.plot(x, x**2)
plt.plot(x, np.exp(x))
plt.title("Normal scale")

plt.subplot(1, 2, 2)
plt.plot(x, x**2)
plt.plot(x, np.exp(x))
plt.yscale("log") #yscale = set_yscale
plt.title("Logarithmic scale (y)")

plt.subplots_adjust(right = 1.5)
plt.show()

# %%
# your code here - 2nd way

fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2,x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2,x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")

plt.show()

# %% [markdown]
# ### Using DataFrames

# %%
vehicles = pd.read_csv("../vehicles.csv")
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here

plt.scatter(vehicles["Combined MPG"], vehicles ["Highway MPG"])
plt.show ()

# %%
# or
plt.scatter(x = "Combined MPG", y = "Highway MPG", data = vehicles)
plt.show()

# %%
# or
vehicles.plot.scatter(x = "Combined MPG", y = "Highway MPG")
plt.show()

# %%
# you can plot the color as a variation of the values of a column 
vehicles.plot.scatter(x = "Combined MPG", y = "Highway MPG", c="Cylinders")
plt.show()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
grouped_fuel_type = vehicles[["Fuel Type", "City MPG"]].groupby(["Fuel Type"]).mean().reset_index()
grouped_fuel_type.head() # check what you want to plot
# reset_index necessary as without, Fuel Type would have been the index
# The default behavior of pandas groupby is to turn the group by columns into index and remove them 
# from the list of columns of the dataframe.
# Out:
#                  Fuel Type   City MPG
# 0                      CNG  15.966667
# 1                   Diesel  21.173436
# 2          Gasoline or E85  15.347280
# 3  Gasoline or natural gas  13.700000
# 4      Gasoline or propane  12.000000

# %%
grouped_fuel_type.plot.bar(x = "Fuel Type", y = "City MPG")
plt.show()

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
vehicles["Fuel Barrels/Year"].plot.hist(bins=20)
plt.show()

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*, ...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported.
#
# ...
